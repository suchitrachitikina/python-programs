# %% [markdown]
# <a href="https://colab.research.google.com/github/suchitrachitikina/python-programs/blob/main/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Arthemetic operators
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
print("Floor Division =", a // b)
print("Modulus =", a % b)
print("Exponent =", a ** b)
# Out:
# Enter first number: 4
# Enter second number: 2
# Addition = 6
# Subtraction = 2
# Multiplication = 8
# Division = 2.0
# Floor Division = 2
# Modulus = 0
# Exponent = 16

# %%
#Comparison operators
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Equal =", a == b)
print("Not Equal =", a != b)
print("Greater Than =", a > b)
print("Less Than =", a < b)
print("Greater Than or Equal =", a >= b)
print("Less Than or Equal =", a <= b)
# Out:
# Enter first number: 1
# Enter second number: 2
# Equal = False
# Not Equal = True
# Greater Than = False
# Less Than = True
# Greater Than or Equal = False
# Less Than or Equal = True

# %%
#Logical operators
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("AND =", a > 0 and b > 0)
print("OR =", a > 0 or b > 0)
print("NOT =", not (a > 0))
# Out:
# Enter first number: 1
# Enter second number: -1
# AND = False
# OR = True
# NOT = False

# %%
#Assignment operators
a = int(input("Enter a number: "))
b = int(input("Enter another number: "))

a += b
print("After += :", a)

a -= b
print("After -= :", a)

a *= b
print("After *= :", a)

a //= b
print("After //= :", a)
# Out:
# Enter a number: 1
# Enter another number: 2
# After += : 3
# After -= : 1
# After *= : 2
# After //= : 1

# %%
#Bitwise operators
a = int(input("Enter first integer: "))
b = int(input("Enter second integer: "))

print("AND =", a & b)
print("OR =", a | b)
print("XOR =", a ^ b)
print("NOT =", ~a)
print("Left Shift =", a << 1)
print("Right Shift =", a >> 1)
# Out:
# Enter first integer: 1
# Enter second integer: 2
# AND = 0
# OR = 3
# XOR = 3
# NOT = -2
# Left Shift = 2
# Right Shift = 0

# %%
#Membership operators
text = input("Enter a string: ")
ch = input("Enter a character: ")

print(ch in text)
print(ch not in text)
# Out:
# Enter a string: suchitra
# Enter a character: z
# False
# True

# %%
#Identify operator
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print(a is b)
print(a is not b)
# Out:
# Enter first number: 1
# Enter second number: 2
# False
# True
