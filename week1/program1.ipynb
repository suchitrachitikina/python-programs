# %% [markdown]
# <a href="https://colab.research.google.com/github/suchitrachitikina/python-programs/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
print("suchitra")
# Out:
# hello
# suchitra

# %%
#Arthemetic operators
a=int(input("Enter a value:"))
b=int(input("Enter a value:"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# Enter a value:9
# Enter a value:10
# 19
# -1
# 90
# 0.9
# 9
# 3486784401
# 0

# %%
#comparison operator
a=int(input("Enter a value:"))
b=int(input("Enter a value:"))
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a!=b)
print(a==b)
# Out:
# Enter a value:4
# Enter a value:2
# True
# False
# True
# False
# True
# False

# %%
#logical operator
a=int(input("Enter a value:"))
b=int(input("Enter a value:"))
print(a>b and a<b)
print(a>b or a<b)
print(not a>b)
# Out:
# Enter a value:4
# Enter a value:2
# False
# True
# False

# %%
#membership operator
a=6
b=6
print(b is a)
# Out:
# True
